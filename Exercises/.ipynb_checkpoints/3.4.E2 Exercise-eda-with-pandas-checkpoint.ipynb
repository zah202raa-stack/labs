# %% [markdown]
# <img src="../assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Introduction to `pandas`
#
# ---

# %% [markdown]
# ### About
# `pandas` is the most popular python package for managing datasets and is used extensively by data scientists.
#
# ### Learning Objectives
# - Explore the characteristics of a dataset at a high level with `pandas`.
#
# ### Notebook Guide
# An exercise in practising:
#
# - Reading data with `pandas`
# - Exploring and manipulating data with `pandas`
#     - Column operations
#     - Filtering
#     - Sorting
#     - Writing data

# %% [markdown]
# # Scenario
#
# You're an analyst working for CoolBricks - a new toy company who wants to compete with LEGO by producing their own bricks and sets. To better understand what kind of sets to create and at what price points, you are tasked with analyzing LEGO's catalogue over time.
#
# The data comes from Kaggle: [https://www.kaggle.com/datasets/alexracape/lego-sets-and-prices-over-time](https://www.kaggle.com/datasets/alexracape/lego-sets-and-prices-over-time)
#
# We are going to use `pandas` to read and explore this data.
#
# ### Business question
#
# What is the biggest set we could build (in terms of number of pieces) and what sort of price would we want to charge?

# %% [markdown]
# #### 1. Import `pandas` and read in the LEGO dataset

# %%
import pandas as pd
lego=pd.read_csv('./data/lego.csv')
lego
# Out:
#          Set_ID                     Name  Year      Theme    Theme_Group  \
# 0          75-1            PreSchool Set  1975  PreSchool     Pre-school
# 1          77-1            PreSchool Set  1975  PreSchool     Pre-school
# 2         077-1           Pre-School Set  1975      Duplo     Pre-school
# 3          78-1            PreSchool Set  1975  PreSchool     Pre-school
# 4          78-3                Basic Set  1975  Samsonite        Vintage
# ...         ...                      ...   ...        ...            ...
# 14931  854242-1        Creeper Key Chain  2023       Gear  Miscellaneous
# 14932  854243-1          Steve Key Chain  2023       Gear  Miscellaneous
# 14933  854244-1         Piglin Key Chain  2023       Gear  Miscellaneous
# 14934  854245-1   Fennec Shand Key Chain  2023       Gear  Miscellaneous
# 14935  854246-1  Scout Trooper Key Chain  2023       Gear  Miscellaneous
#
#                    Subtheme Category        Packaging  Num_Instructions  \
# 0                       NaN   Normal  {Not specified}                 0
# 1                       NaN   Normal  {Not specified}                 0
# 2                       NaN   Normal  {Not specified}                 0
# 3                       NaN   Normal  {Not specified}                 0
# 4                 Basic set   Normal              Box                 0
# ...                     ...      ...              ...               ...
# 14931  Key Chains/Minecraft     Gear              Tag                 0
# 14932  Key Chains/Minecraft     Gear              Tag                 0
# 14933  Key Chains/Minecraft     Gear              Tag                 0
# 14934  Key Chains/Star Wars     Gear              Tag                 0
# 14935  Key Chains/Star Wars     Gear              Tag                 0
#
#           Availability  Pieces  Minifigures  Owned  Rating  USD_MSRP  \
# 0      {Not specified}    16.0          NaN   10.0     0.0       NaN
# 1      {Not specified}    20.0          NaN   11.0     0.0       NaN
# 2      {Not specified}    21.0          NaN   10.0     0.0       NaN
# 3      {Not specified}    32.0          NaN    8.0     0.0       NaN
# 4      {Not specified}   330.0          NaN   10.0     0.0       NaN
# ...                ...     ...          ...    ...     ...       ...
# 14931   LEGO exclusive     NaN          NaN    2.0     0.0      5.99
# 14932   LEGO exclusive     NaN          NaN    2.0     0.0      5.99
# 14933   LEGO exclusive     NaN          NaN    2.0     0.0      5.99
# 14934   LEGO exclusive     NaN          NaN   88.0     0.0      5.99
# 14935   LEGO exclusive     NaN          NaN  107.0     0.0      5.99
#
#        Total_Quantity  Current_Price
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 0.0            NaN
# 3                 NaN            NaN
# 4                 0.0            NaN
# ...               ...            ...
# 14931             NaN            NaN
# 14932             NaN            NaN
# 14933             NaN            NaN
# 14934             NaN            NaN
# 14935             NaN            NaN
#
# [14936 rows x 17 columns]

# %% [markdown]
# #### 2. So we can focus on just the columns that help answer the question, select only the following columns into a new `DataFrame` variable:
#
# - name
# - theme
# - number of pieces
# - retail price (USD_MSRP)

# %%
foc_lego=lego[['Name','Theme','Pieces','USD_MSRP']]
foc_lego
# Out:
#                           Name      Theme  Pieces  USD_MSRP
# 0                PreSchool Set  PreSchool    16.0       NaN
# 1                PreSchool Set  PreSchool    20.0       NaN
# 2               Pre-School Set      Duplo    21.0       NaN
# 3                PreSchool Set  PreSchool    32.0       NaN
# 4                    Basic Set  Samsonite   330.0       NaN
# ...                        ...        ...     ...       ...
# 14931        Creeper Key Chain       Gear     NaN      5.99
# 14932          Steve Key Chain       Gear     NaN      5.99
# 14933         Piglin Key Chain       Gear     NaN      5.99
# 14934   Fennec Shand Key Chain       Gear     NaN      5.99
# 14935  Scout Trooper Key Chain       Gear     NaN      5.99
#
# [14936 rows x 4 columns]

# %% [markdown]
# #### 3. How many sets have a price greater than $100?

# %%
foc_lego[
    foc_lego['USD_MSRP'] > 100
    ].count()
# Out:
# Name        380
# Theme       380
# Pieces      374
# USD_MSRP    380
# dtype: int64

# %% [markdown]
# #### 4. What are the top 10 sets with the highest number of pieces?

# %%
foc_lego.sort_values('Pieces' , ascending=False ).head(10)
# Out:
#                                    Name           Theme   Pieces  USD_MSRP
# 13559                         World Map             Art  11695.0    249.99
# 13946                      Eiffel Tower           Icons  10001.0    629.99
# 13449                           Titanic           Icons   9090.0    679.99
# 12942                         Colosseum           Icons   9036.0    549.99
# 11928                 Millennium Falcon       Star Wars   7541.0    849.99
# 14380                   The Razor Crest       Star Wars   6187.0    599.99
# 14440  The Lord of the Rings: Rivendell           Icons   6167.0    499.99
# 14807              NINJAGO City Markets         Ninjago   6163.0    369.99
# 12369                   Hogwarts Castle    Harry Potter   6020.0    469.99
# 11437                         Taj Mahal  Creator Expert   5923.0    369.99

# %% [markdown]
# #### 5. Create a new column to measure "price per piece", which should be the price (USD_MSRP) divided by the number of pieces

# %%
foc_lego['ppp'] = (foc_lego['USD_MSRP'])/( foc_lego['Pieces'])
foc_lego.head(50)
# Out:
#                                              Name                     Theme  \
# 0                                   PreSchool Set                 PreSchool
# 1                                   PreSchool Set                 PreSchool
# 2                                  Pre-School Set                     Duplo
# 3                                   PreSchool Set                 PreSchool
# 4                                       Basic Set                 Samsonite
# 5                                      Locomotive                    Trains
# 6                          Mobile Crane and Wagon                    Trains
# 7                                    Tanker Wagon                    Trains
# 8                          Passenger Sleeping Car                    Trains
# 9                                         Station                    Trains
# 10                           Train Set with Motor                    Trains
# 11                                       Farm Set  Building Set with People
# 12                                       Airplane  Building Set with People
# 13                            Building Ideas Book                     Books
# 14                           Helicopter and Pilot  Building Set with People
# 15                                         Family  Building Set with People
# 16                                  Farming Scene  Building Set with People
# 17                                       Windmill                  LEGOLAND
# 18                                       Hospital                  LEGOLAND
# 19                                        Harbour                  LEGOLAND
# 20                                      Wild West                  LEGOLAND
# 21                   Space Module with Astronauts                  LEGOLAND
# 22                                  1913 Cadillac                 Hobby Set
# 23                                   1926 Renault                 Hobby Set
# 24                                      Formula 1                 Hobby Set
# 25                                        Biplane                  LEGOLAND
# 26                              Rescue Helicopter                  LEGOLAND
# 27                                   Mobile Crane                  LEGOLAND
# 28                         Bricks and half bricks                     Duplo
# 29              Bricks and half bricks and arches                     Duplo
# 30             Bricks and half bricks and trolley                     Duplo
# 31  Bricks and half bricks and arches and trolley                     Duplo
# 32         Bricks and half bricks and two tolleys                     Duplo
# 33             Bricks and half bricks all colours                     Duplo
# 34                                     Brick Yard                  LEGOLAND
# 35                                       Forklift                  LEGOLAND
# 36                                  Police Patrol                  LEGOLAND
# 37                                Air Transporter                  LEGOLAND
# 38                               Road Repair Crew                  LEGOLAND
# 39                       Fire engine with firemen                  LEGOLAND
# 40                                Transport Truck                  LEGOLAND
# 41                                     London Bus                  LEGOLAND
# 42                                        Tractor  Building Set with People
# 43                            Holdall Storage Bag                      Gear
# 44                                      Super Set    Universal Building Set
# 45                         Basic Building Set, 3+                     Basic
# 46                         Basic Building Set, 3+                     Basic
# 47                         Basic Building Set, 3+                     Basic
# 48                         Basic Building Set, 3+                     Basic
# 49                         Basic Building Set, 3+                     Basic
#
#     Pieces  USD_MSRP  ppp
# 0     16.0       NaN  NaN
# 1     20.0       NaN  NaN
# 2     21.0       NaN  NaN
# 3     32.0       NaN  NaN
# 4    330.0       NaN  NaN
# 5     87.0       NaN  NaN
# 6     86.0       NaN  NaN
# 7     83.0       NaN  NaN
# 8     82.0       NaN  NaN
# 9    293.0       NaN  NaN
# 10   369.0       NaN  NaN
# 11   526.0       NaN  NaN
# 12    89.0       NaN  NaN
# 13     1.0       NaN  NaN
# 14    49.0       NaN  NaN
# 15   103.0       NaN  NaN
# 16   120.0       NaN  NaN
# 17   215.0       NaN  NaN
# 18   229.0       NaN  NaN
# 19   518.0       NaN  NaN
# 20   602.0       NaN  NaN
# 21   364.0       NaN  NaN
# 22   200.0       NaN  NaN
# 23   237.0       NaN  NaN
# 24   197.0       NaN  NaN
# 25    18.0       NaN  NaN
# 26    62.0       NaN  NaN
# 27    46.0       NaN  NaN
# 28    20.0       NaN  NaN
# 29   121.0       NaN  NaN
# 30    17.0       NaN  NaN
# 31   240.0       NaN  NaN
# 32   168.0       NaN  NaN
# 33   640.0       NaN  NaN
# 34   216.0       NaN  NaN
# 35    21.0       NaN  NaN
# 36    49.0       NaN  NaN
# 37    39.0       NaN  NaN
# 38    57.0       NaN  NaN
# 39    62.0       NaN  NaN
# 40    65.0       NaN  NaN
# 41   110.0       NaN  NaN
# 42    93.0       NaN  NaN
# 43     NaN       NaN  NaN
# 44     NaN       NaN  NaN
# 45   152.0       NaN  NaN
# 46   217.0       NaN  NaN
# 47   258.0       NaN  NaN
# 48   258.0       NaN  NaN
# 49   382.0       NaN  NaN

# %% [markdown]
# #### 6. Use this column to find the top 10 most expensive sets by "price per piece"

# %%
foc_lego.sort_values('ppp', ascending=False).head(10)
# Out:
#                                                     Name  \
# 13892                 Character Pack Series 3 - Complete
# 13806  LEGO Minifigures - Marvel Studios Series {Box ...
# 14251  LEGO Minifigures - Series 22 {Box of 6 random ...
# 9653                               EV3 Intelligent Brick
# 6342                               NXT Intelligent Brick
# 7695                       Intelligent NXT Brick (Black)
# 13755                                          Small Hub
# 9654                             DC Rechargeable Battery
# 8197                         NXT DC Rechargeable Battery
# 12927                                          Boost Hub
#
#                          Theme  Pieces  USD_MSRP      ppp
# 13892              Super Mario     0.0      4.99      inf
# 13806  Collectable Minifigures     0.0     29.94      inf
# 14251  Collectable Minifigures     0.0     29.94      inf
# 9653                Mindstorms     1.0    224.95  224.950
# 6342                Mindstorms     1.0    169.99  169.990
# 7695                Mindstorms     1.0    169.99  169.990
# 13755                Education     2.0    214.95  107.475
# 9654                 Education     1.0     99.95   99.950
# 8197                 Education     1.0     79.99   79.990
# 12927               Powered Up     1.0     79.99   79.990

# %% [markdown]
# #### 7. Narrow the search to show the top 10 most expensive sets by "price per piece" for the "Icons" theme *only*

# %%
foc_lego[foc_lego['Theme'] == 'Icons'].sort_values('ppp', ascending=False).head(10)
# Out:
#                                   Name  Theme  Pieces  USD_MSRP       ppp
# 13941                    Optimus Prime  Icons  1508.0    179.99  0.119357
# 13943       Chevrolet Camaro Z/28 1969  Icons  1456.0    169.99  0.116751
# 13450                      Porsche 911  Icons  1458.0    169.99  0.116591
# 13440       Adidas Originals Superstar  Icons   731.0     79.99  0.109425
# 13939  Back to the Future Time Machine  Icons  1872.0    199.99  0.106832
# 13942                     Loop Coaster  Icons  3756.0    399.99  0.106494
# 14441   Land Rover Classic Defender 90  Icons  2336.0    239.99  0.102735
# 13446       Queer Eye – The Fab 5 Loft  Icons   974.0     99.99  0.102659
# 12940              Ghostbusters ECTO-1  Icons  2352.0    239.99  0.102037
# 13617              Everyone is Awesome  Icons   346.0     34.99  0.101127

# %% [markdown]
# #### 8. What are the top 10 cheapest sets by "price per piece" in the "Icons" theme?

# %%
foc_lego[foc_lego['Theme'] == 'Icons'].sort_values('ppp', ascending=True).head(10)
# Out:
#                                           Name  Theme   Pieces  USD_MSRP  \
# 13439                              Bonsai Tree  Icons    878.0     49.99
# 14576                                Daffodils  Icons    216.0     12.99
# 12942                                Colosseum  Icons   9036.0    549.99
# 14438                 Dried Flower Centrepiece  Icons    812.0     49.99
# 13946                             Eiffel Tower  Icons  10001.0    629.99
# 13443                  Camp Nou - FC Barcelona  Icons   5509.0    349.99
# 14437                       Wildflower Bouquet  Icons    939.0     59.99
# 13948                               Succulents  Icons    771.0     49.99
# 13947                      Holiday Main Street  Icons   1514.0     99.99
# 13938  Real Madrid - Santiago Bernabéu Stadium  Icons   5876.0    399.99
#
#             ppp
# 13439  0.056936
# 14576  0.060139
# 12942  0.060867
# 14438  0.061564
# 13946  0.062993
# 13443  0.063531
# 14437  0.063887
# 13948  0.064838
# 13947  0.066044
# 13938  0.068072

# %% [markdown]
# #### 9. Export the `DataFrame` you created in question 2. to a new CSV file.

# %%
foc_lego.to_csv('lego_analyzed.csv', index=False)

# %% [markdown]
# ### Reflection
#
# What is your answer to the business question? Here it is as a reminder:
#
# > What is the biggest set we could build (in terms of number of pieces) and what sort of price would we want to charge?
#
# Reflect on your experience. How was working with `pandas` compared to other tools you already know?
