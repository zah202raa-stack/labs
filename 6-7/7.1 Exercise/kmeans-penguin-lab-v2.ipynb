# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
#
# # Clustering and K-Means Lab
#
#
# ---

# %% [markdown]
# ### Lab Objectives
# * Penguin dataset is used mainly for classification as we have labels, however, we will assume we do not have a label and we would use the dataset for clustering

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# #### Describing the data
#
# <img src='attachment:image.png' width=400>

# %% [markdown]
# **Columns in the dataset**
# - Species: penguin species (Chinstrap, Adélie, or Gentoo)
# - Island: island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# - flipper_length_mm: flipper length (mm)
# - body_mass_g: body mass (g)
# - Sex: penguin sex

# %%
# Load the dataset from seaborn using sns.load_dataset. It is called penguins
df = sns.load_dataset("penguins")

# Show the head
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# check columns info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 24.9 KB

# %%
# do we have any nulls?
df.isnull().sum()

#yes there is some null
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# Drop null values from the dataset

df=df.dropna()

# check the shape after dropping
df.shape
# Out:
# (333, 7)

# %%
# Create the scatter plot between bill length and flipper length
plt.style.use('ggplot')

# Create the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df, 
    x="bill_length_mm", 
    y="flipper_length_mm"
)

plt.xlabel("bill_length_mm")
plt.ylabel("flipper_length_mm")
plt.show()

# %%
# No code here

# %%
# set our X features to be bill length and flipper length
X = df[["bill_length_mm", "flipper_length_mm"]]

# %%
# Important step: scale the data
sc=StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
# instantiate kmeans model with 8 cluster, random state 7
km = KMeans(n_clusters=8, random_state=7)
km.fit(X_scaled)
# Out:
# KMeans(random_state=7)

# %%
# get centroids of model1
# Inverse the scaling of cluster_centers_ and save it into a variable centers
centers = sc.inverse_transform(km.cluster_centers_)

# Create a dataframe called cluster1 contains the centers, define the column names as x1 and y1
cluster1 = pd.DataFrame(centers, columns=['x1', 'y1'])

# %%
# create two scatter plots:
# first:  from penguins main dataframe,plotting bill length against flipper length
# second: from clusters dataframe that you have created in previous code cell
plt.figure(figsize=(10, 8))
ax = df.plot(
    kind="scatter",
    x="bill_length_mm",
    y="flipper_length_mm",
    figsize=(10, 8),
    color="steelblue",
    label="Penguins"
)

cluster1.plot(
    kind="scatter",
    x="x1",
    y="y1",
    marker="*",
    c="red",
    s=550,
    ax=ax,
    label="Centroids"
)

plt.xlabel('bill_length_mm')
plt.ylabel('flipper_length_mm')
plt.title('Penguins Main DataFrame and Cluster Centroids')
plt.legend()
plt.show()
plt.show()

# %%
# instantiate kmeans model with 3 cluster, random state 7
km = KMeans(n_clusters=3, random_state=7)

# fit the model
km.fit(X_scaled)

# what are the models cluster centers?
print(km.cluster_centers_)
# Out:
# [[-0.96427851 -0.80518575]
#  [ 0.66403058  1.15087842]
#  [ 0.9235766  -0.37501448]]

# %%
# get centroids of model2
# inverse the scaling of cluster_centers_ and save it into a variable centers2
centers2 = sc.inverse_transform(km.cluster_centers_)

# create a dataframe called cluster2 contains the centers,
# define the column names as x1 and y1
cluster2 = pd.DataFrame(centers2, columns=['x1', 'y1'])

# %%
# create two scatter plots:
# first:  from penguins main dataframe,plotting bill length against flipper length
# second: from clusters dataframe that you have created in previous code cell
ax = df.plot(
    kind="scatter",
    x="bill_length_mm",
    y="flipper_length_mm",
    figsize=(10, 8),
    color="steelblue",
    label="Penguins"
)

cluster2.plot(
    kind="scatter",
    x="x1",
    y="y1",
    marker="*",
    c="red",
    s=550,
    ax=ax,
    label="Centroids"
)

plt.xlabel('bill_length_mm')
plt.ylabel('flipper_length_mm')
plt.title('Penguins and Cluster Centroids')
plt.legend()
plt.show()

# %%
# create a column cluster_labels in penguins dataframe that has the predictions
df['cluster_labels'] = km.labels_

# display the penguins dataframe with the species and cluster_labels columns
df[['species', 'cluster_labels']]
# Out:
#     species  cluster_labels
# 0    Adelie               0
# 1    Adelie               0
# 2    Adelie               0
# 4    Adelie               0
# 5    Adelie               0
# ..      ...             ...
# 338  Gentoo               1
# 340  Gentoo               1
# 341  Gentoo               1
# 342  Gentoo               1
# 343  Gentoo               1
#
# [333 rows x 2 columns]

# %% [markdown]
# > Let's see if the model matches the correct cluster groups or not

# %%
# make a crosstab in penguins dataframe between species and cluster_labels
pd.crosstab(df['species'], df['cluster_labels'])
# Out:
# cluster_labels    0    1   2
# species
# Adelie          141    1   4
# Chinstrap         5    4  59
# Gentoo            0  118   1
