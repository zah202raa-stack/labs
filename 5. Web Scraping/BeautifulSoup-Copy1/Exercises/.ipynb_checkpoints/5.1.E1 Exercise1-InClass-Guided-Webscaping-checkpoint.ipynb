# %% [markdown]
# ## In-Class Guided Exercise:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Import needed libraries

# %%
import requests
import httpx  # if you want to use httpx instead of requests

import pandas as pd
from bs4 import BeautifulSoup
from time import sleep

# %% [markdown]
# ### Steps on using BeautifulSoup:
# #### 1. Use `requests` to access the url of the web page you want to scrape

# %%
url="https://www.amazon.sa/-/en/s?k=Computer+Tablets&i=computers&rh=n%3A16966433031&language=en&c=ts&qid=1706531941&ts_id=16966433031&ref=sr_pg_1"
hdr={"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 YaBrowser/23.3.0.1922 (beta) Yowser/2.5 Safari/537.3-449"}
html = requests.get(url,headers=hdr)

# %%
# Check the status_code
html.status_code
# 200 mean OK
# Out:
# 200

# %%
# show the first 2000 characters of the html 
html.text[:2000]
# Out:
# '<!doctype html><html lang="en-ae" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);\n\n\n    var ue_err_chan = \'jserr-rw\';\n(function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL=""+(e.location?e.location.href:"");b.logLevel=c;b.attribution=f.attribution||b.attribution;a.erl.push({ex:f,info:b})}}function l(a,b,c,e,g){d.ueLogError({m:a,f:b,l:c,c:""+e,err:g,fromOnError:1,args:arguments},g?{attribution:g.attribution,logLevel:g.logLevel}:void 0);return!1}var k="FATAL",m="ERROR",n="WARN",p="DOWNGRADED",a={ec:0,ecf:0,\npec:0,ts:0,erl:[],ter:[],buffer:[],mxe:50,startTimer:function(){a.ts++;setInterval(function(){d.ue&&a.pec<a.ec&&d.uex("at");a.p'

# %% [markdown]
# #### 2. Now that we have the web page, we can parse it with beautifulsoup:

# %%
soup = BeautifulSoup(html.text, 'html.parser') #<shift + tab>

# %% [markdown]
# - Get the title of the page using the tag 'title':

# %%
soup.title.text
# Out:
# 'Amazon.sa : Computer Tablets'

# %% [markdown]
# #### 3. Get all the items in that page
# - Use `inspect` on the web page to know how to collect the items
# - Create a variable that contains all the items in that web page

# %%
# bigger box selection
amazon = soup.find_all('div' ,class_="sg-col-4-of-4 sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-8 sg-col-4-of-20")

# %%
# Check one of the items collected
amazon[0]
# Out:
# <div class="sg-col-4-of-4 sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-8 sg-col-4-of-20" data-asin="B0FQ5XPNH7" data-component-type="s-search-result" data-index="5" data-uuid="533c39f7-8fe4-4d51-849f-934df11f1918" id="533c39f7-8fe4-4d51-849f-934df11f1918" role="listitem"><div class="sg-col-inner"><div cel_widget_id="MAIN-SEARCH_RESULTS-5" class="s-widget-container s-spacing-small s-widget-container-height-small celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results_4" data-csa-c-item-id="amzn1.asin.1.B0FQ5XPNH7" data-csa-c-pos="4" data-csa-c-type="item" data-csa-op-log-render=""><span class="a-declarative" data-action="puis-card-container-declarative" data-csa-c-func-deps="aui-da-puis-card-container-declarative" data-csa-c-item-id="amzn1.asin.B0FQ5XPNH7" data-csa-c-owner="puis" data-csa-c-posx="4" data-csa-c-type="item" data-render-id="r3152lce0z4qak2lo5e53z26lbp" data-version-id="v2j36pgodmvsbo2tmbaj1p6v8t0"><div class="puis-card-container puis-overflow-hidden s-card-container aok-relative puis-expand-height puis-include-content-margin puis puis-v2j36pgodmvsbo2tmbaj1p6v8t0 s-latency-cf-section puis-card-border" data-cy="asin-faceout-container"><div class="a-section a-spacing-base desktop-grid-content-view"><div class="a-section a-spacing-none puis-status-badge-container aok-relative s-grid-status-badge-container puis-expand-height"><span aria-label="Amazon's Choice"><span class="rush-component mvt-badge-padding-3 mvt-badge-placement-3 mvt-badge-rectangle-shape mvt-badge-border-radius mvt-badge-font" data-component-props='{"asin":"B0FQ5XPNH7","badgeType":"amazons-choice"}' data-component-type="s-status-badge-component" data-render-id="r3152lce0z4qak2lo5e53z26lbp" data-version-id="v2j36pgodmvsbo2tmbaj1p6v8t0"><div class="a-row a-badge-region"><span aria-labelledby="B0FQ5XPNH7-amazons-choice-label B0FQ5XPNH7-amazons-choice-supplementary" class="a-badge" data-a-badge-supplementary-position="right" data-a-badge-type="status" id="B0FQ5XPNH7-amazons-choice" role="group" tabindex="0"><span aria-hidden="true" class="a-badge-label" data-a-badge-color="mvt-badge-color-squid-ink" id="B0FQ5XPNH7-amazons-choice-label"><span class="a-badge-label-inner a-text-ellipsis"><span class="a-badge-text" data-a-badge-color="mvt-badge-text-color-white">Amazon's </span><span class="a-badge-text" data-a-badge-color="mvt-badge-text-color-white">Choice</span></span></span><span aria-hidden="true" class="a-badge-supplementary-text a-text-ellipsis" id="B0FQ5XPNH7-amazons-choice-supplementary">for "Computer Tablets"</span></span></div></span></span></div><div class="s-product-image-container aok-relative s-text-center s-image-overlay-grey puis-image-overlay-grey s-padding-left-small s-padding-right-small puis-spacing-small s-height-equalized puis puis-v2j36pgodmvsbo2tmbaj1p6v8t0" data-cy="image-container"><span class="rush-component" data-component-type="s-product-image" data-render-id="r3152lce0z4qak2lo5e53z26lbp" data-version-id="v2j36pgodmvsbo2tmbaj1p6v8t0"><a aria-hidden="true" class="a-link-normal s-no-outline" href="/-/en/Samsung-Galaxy-Android-Storage-Version/dp/B0FQ5XPNH7/ref=sr_1_4?c=ts&amp;dib=eyJ2IjoiMSJ9.eSSuf18Sf-BXbo6_E3a0DsgRy-lwtdQ8x5wmxxJYep2MHqlna8KJwiKvwSLUHrYM8IGJ1AJeAS5X7oOZ_Igl5YFTAOyUUaikpc6ghVDQcb3WmxwueUWtS-G8-E5R9AR5clzACbpUtG_eTCBP8m9VvAU3iJiQ3uJ8FcGa3N88VTwnp2Om_h33VIpo3_PU4rx9td3ZJ6h6DfMEscnCRiIyMQ-OgGJaNi4l0ZExd2vfqS1dJz_uzZ1BRZo7SplcX2_9r5dtCkkiD4dIpP2CW3FugtwOTvgL6Dfl_8N5wI18I64.1IHdUvbS7ft23T9byvDaj16_A1ywwJ_ZYfo7C5Dyros&amp;dib_tag=se&amp;keywords=Computer+Tablets&amp;qid=1784013007&amp;s=electronics&amp;sr=1-4&amp;ts_id=16966433031" tabindex="-1"><div class="a-section aok-relative s-image-square-aspect"><img alt='Samsung Galaxy Tab A11, Wifi, Android Tablet, Gray, 8GB RAM, 128GB Storage, 8.7" Screen (KSA Version)' aria-hidden="true" class="s-image" data-image-index="4" data-image-latency="s-product-image" data-image-load="" data-image-source-density ...

# %% [markdown]
# #### 4. Using one item, try to collect the information that you want to scrape
# - In our web page here, we want to collect the following:
#     - Product Title
#     - Link
#     - Price
#     - Rating
#     - Number of Reviews

# %% [markdown]
# ##### 4.1 *Get the Product Title*

# %%
amazon[0].find('h2').text.strip()
# Out:
# 'Samsung Galaxy Tab A11, Wifi, Android Tablet, Gray, 8GB RAM, 128GB Storage, 8.7" Screen (KSA Version)'

# %% [markdown]
# ##### 4.2 *Get the Link*

# %%
'https://www.amazon.sa'+ amazon[0].find('a')['href']
# Out:
# 'https://www.amazon.sa/-/en/Samsung-Galaxy-Android-Storage-Version/dp/B0FQ5XPNH7/ref=sr_1_4?c=ts&dib=eyJ2IjoiMSJ9.eSSuf18Sf-BXbo6_E3a0DsgRy-lwtdQ8x5wmxxJYep2MHqlna8KJwiKvwSLUHrYM8IGJ1AJeAS5X7oOZ_Igl5YFTAOyUUaikpc6ghVDQcb3WmxwueUWtS-G8-E5R9AR5clzACbpUtG_eTCBP8m9VvAU3iJiQ3uJ8FcGa3N88VTwnp2Om_h33VIpo3_PU4rx9td3ZJ6h6DfMEscnCRiIyMQ-OgGJaNi4l0ZExd2vfqS1dJz_uzZ1BRZo7SplcX2_9r5dtCkkiD4dIpP2CW3FugtwOTvgL6Dfl_8N5wI18I64.1IHdUvbS7ft23T9byvDaj16_A1ywwJ_ZYfo7C5Dyros&dib_tag=se&keywords=Computer+Tablets&qid=1784013007&s=electronics&sr=1-4&ts_id=16966433031'

# %% [markdown]
# ##### 4.3 *Get the Price*

# %%
amazon[0].find('span', class_="a-price-whole").text +amazon[0].find('span', class_="a-price-fraction").text
# Out:
# '640.53'

# %% [markdown]
# ##### 4.4 *Get the Rating*

# %%
amazon[0].find('span' , class_="a-icon-alt" ).text
# Out:
# '4.4 out of 5 stars'

# %%
# getting only the first part of the rating instead of all 
# or you can split it at a later stage
amazon[0].find('span' , class_="a-icon-alt" ).text.split()[0]
# Out:
# '4.4'

# %% [markdown]
# ##### 4.5 *Get Number of Reviews*

# %%
# same problem you faced in the previous cell will be faced here

# %%
amazon[0].find('span' , class_="a-size-mini puis-normal-weight-text s-underline-text").text.replace('(','').replace(')','')

# %% [markdown]
# #### 5. Collect all the information of all the items using `loops`
# - Now, once we know how to get in information we want from one item, we can now collect all the information from all the items using `for loop`
# - First of all, we need to create a list for each info we want to collect and append the scraped info to those lists

# %%
title = []
price = []
rev = []
link_page = []
rating = []

# define the rest of lists to be used to scrape the details of each element
# your code here

for i in amazon:
    try:
        title.append(i.find('h2').text.strip())
    except:
        title.append(None)

    try:
        price.append(i.find('span', class_="a-price-whole").text +i.find('span', class_="a-price-fraction").text )
        
    except:
        price.append(None)

    try:
        rev.append(i.find('span' , class_="a-size-mini puis-normal-weight-text s-underline-text").text)
    except:
        rev.append(None)

    try:
        link_page.append('https://www.amazon.sa'+ i.find('a')['href'])
    except:
        link_page.append(None)

    try:
        rating.append(i.find('span' , class_="a-icon-alt" ).text.split()[0])
    except:
        rating.append(None)

# %% [markdown]
# #### 6. Modify the previous `loop` to collect multiple web pages
# - In below code, we collect the web pages from 1 to 5 of that site
# - Notice that the only difference from page to page is the page number which we can use in the `for loop` using the curly brackets `{}`

# %%
title = []
price = []
rev = []
link_page = []
rating = []

# define the rest of lists to be used to scrape the details of each element

# your code here

for p in range(1,6):
    url = f'https://www.amazon.sa/-/en/s?k=Computer+Tablets&i=computers&rh=n%3A16966433031&language=en&c=ts&qid=1706531941&ts_id=16966433031&ref=sr_pg_{p}'
    link =  requests.get(url)
    soup = BeautifulSoup(link.text, 'html.parser')
    amazon = soup.find_all('div' ,class_="sg-col-4-of-4 sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-8 sg-col-4-of-20")
    for i in amazon:
        try:
            title.append(i.find('h2').text.strip())
        except:
            title.append(None)
    
        try:
            price.append(i.find('span', class_="a-price-whole").text +i.find('span', class_="a-price-fraction").text )
        except:
            price.append(None)
    
        try:
            rev.append(i.find('span' , class_="a-size-mini puis-normal-weight-text s-underline-text").text.replace('(','').replace(')',''))
        except:
            rev.append(None)
    
        try:
            link_page.append('https://www.amazon.sa'+ i.find('a')['href'])
        except AttributeError:
            link_page.append(None)
    
        try:
            rating.append(i.find('span' , class_="a-icon-alt" ).text.split()[0])
        except:
            rating.append(None)

# %% [markdown]
# #### 7. Create a DataFrame to save all the scraped info. into a table.

# %%
amazon_df=pd.DataFrame({
    'Title': title,
    'Price': price,
    'Reviews': rev,
    'Rating': rating,
    'Link': link_page
})

# %%
amazon_df
# Out:
#                                                 Title     Price Reviews  \
# 0   Samsung Galaxy Tab A11, Wifi, Android Tablet, ...    640.53     110
# 1   HONOR Pad X8b WiFi Tablet 11-Inch 90Hz FHD Dis...    799.00      31
# 2   Samsung Galaxy Tab A11+, WiFi, Android Tablet,...    799.00      51
# 3   HUAWEI MatePad SE 11'' 4+128GB Grey Tablet, Fu...    699.00       7
# 4   HUAWEI MatePad SE 11'' 8+128GB Nebula Grey Tab...    799.00      13
# ..                                                ...       ...     ...
# 91  Tablet 2026 World's First Android 16 Tablet wi...    999.99     530
# 92  TABWEE T60 Android 16 Tablet with Keyboard, 12...    899.99     110
# 93  Microsoft (Refurbished) Surface Pro X 2-In-1 L...  3,299.34     NaN
# 94  10 Inch Android 13 Tablet 12GB RAM+128GB ROM/1...    392.02    1.9K
# 95  Samsung Galaxy Tab A11+, WiFi, Android Tablet,...  1,019.00      51
#
#    Rating                                               Link
# 0     4.4  https://www.amazon.sa/-/en/Samsung-Galaxy-Andr...
# 1     4.1  https://www.amazon.sa/-/en/HONOR-10100mAh-Expa...
# 2     4.0  https://www.amazon.sa/-/en/Samsung-Galaxy-Andr...
# 3     4.0  https://www.amazon.sa/-/en/HUAWEI-MatePad-Full...
# 4     4.4  https://www.amazon.sa/-/en/HUAWEI-MatePad-Full...
# ..    ...                                                ...
# 91    4.5  https://www.amazon.sa/-/en/Android-Display-800...
# 92    4.6  https://www.amazon.sa/-/en/TABWEE-T60-Keyboard...
# 93    NaN  https://www.amazon.sa/-/en/Microsoft-Refurbish...
# 94    4.1  https://www.amazon.sa/-/en/Android-Tablet-Expa...
# 95    4.0  https://www.amazon.sa/-/en/Samsung-Galaxy-Andr...
#
# [96 rows x 5 columns]

# %% [markdown]
# #### 8. Save your dataframe to a `CSV` file
# - Save the output to a csv file (excluding the index)

# %%
# Save the output to a csv file (excluding the index)

amazon_df.to_csv("amazon.csv",index=False)
